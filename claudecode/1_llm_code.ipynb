# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
load_dotenv()
import os

if os.getenv("ANTHROPIC_API_KEY") is None:
    raise ValueError("ANTHROPIC_API_KEY environment variable is not set.")
else:
    print("all set! ANTHROPIC_API_KEY environment variable is set.")
# Out:
# all set! ANTHROPIC_API_KEY environment variable is set.

# %%
llm = ChatAnthropic(model="claude-haiku-4-5-20251001")
response = llm.invoke("""Give me the code to create a pandas dataframe with 3 columns and 5 rows.
Please also generate a python file to store the code. Please.""")
print(response.content)
# Out:
# # Here's the code to create a pandas DataFrame and save it to a Python file
#
# ```python
# import pandas as pd
#
# # Create a DataFrame with 3 columns and 5 rows
# data = {
#     'Column1': [1, 2, 3, 4, 5],
#     'Column2': ['A', 'B', 'C', 'D', 'E'],
#     'Column3': [10.5, 20.3, 15.7, 25.1, 30.9]
# }
#
# df = pd.DataFrame(data)
#
# print(df)
# ```
#
# ## To save this as a Python file:
#
# **Step 1:** Create a new file called `create_dataframe.py`
#
# **Step 2:** Copy the code above into that file
#
# **Step 3:** Run it from your terminal:
# ```bash
# python create_dataframe.py
# ```
#
# ## Output:
# ```
#   Column1 Column2  Column3
# 0       1       A     10.5
# 1       2       B     20.3
# 2       3       C     15.7
# 3       4       D     25.1
# 4       5       E     30.9
# ```
#
# You can customize the column names and data values as needed. Make sure you have pandas installed:
# ```bash
# pip install pandas
# ```
